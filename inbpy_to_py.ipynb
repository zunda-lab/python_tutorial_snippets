# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
from pprint import pprint
import json
import re

# %%
os.chdir("/content/drive/MyDrive/Colab Notebooks/python_activities/python_tutorial_snippets/notebook")
read_fpaths = glob.glob('./**/*.ipynb', recursive=True)
pprint(read_fpaths)
# Out:
# ['./4_controlflow/1_if_statements.ipynb',
#  './4_controlflow/2_for_statements.ipynb',
#  './4_controlflow/3_the_range_function.ipynb',
#  './4_controlflow/4_break_and_continue_statements.ipynb',
#  './4_controlflow/5_else_clauses_on_loops.ipynb',
#  './4_controlflow/6_pass_statements.ipynb',
#  './4_controlflow/7_match_statements.ipynb',
#  './4_controlflow/8_defining_functions.ipynb',
#  './4_controlflow/9_1_default_argument_values.ipynb',
#  './4_controlflow/9_2_keyword_arguments.ipynb',
#  './4_controlflow/9_3_special_parameters.ipynb',
#  './4_controlflow/9_4_arbitrary_argument_lists.ipynb',
#  './4_controlflow/9_5_unpacking_argument_lists.ipynb',
#  './4_controlflow/9_6_lambda_expressions.ipynb',
#  './4_controlflow/9_7_documentation_strings.ipynb',
#  './4_controlflow/9_8_function_annotations.ipynb',
#  './2_interpreter/1_invoking_the_interpreter.ipynb',
#  './3_introduction/__introduction.ipynb',
#  './3_introduction/1_0_an_informal_introduction_to_python.ipynb',
#  './3_introduction/2_first_steps_towards_programming.ipynb',
#  './3_introduction/1_3_lists.ipynb',
#  './3_introduction/1_2_text.ipynb',
#  './3_introduction/1_1_numbers.ipynb']

# %%
for read_fpath in read_fpaths:
    # print(fname)
    result = ""
    dir_path = os.path.dirname(read_fpath)
    basename_without_ext = os.path.splitext(os.path.basename(read_fpath))[0]
    write_fpath = f"{dir_path}/{basename_without_ext}.py"
    print(write_fpath)
    with open(read_fpath, "r") as f:
        nb = json.load(f)
        # pprint(nb)
        for cell in nb["cells"]:
            for source_line in cell["source"]:
                result += source_line
            result += "\n"
            for output in cell["outputs"]:
                output_type = output["output_type"]
                match output_type:
                    case "execute_result":
                        for text_line in output["data"]["text/plain"]:
                            result += f"# {text_line}\n"
                    case "display_data":
                        for text_line in output["data"]["text/plain"]:
                            result += f"# {text_line}\n"
                    case "stream":
                        for text_line in output["text"]:
                            result += f"# {text_line}"
                    case "error":
                        for text_line in output["traceback"]:
                            text_line = re.compile(r'\x1B(?:[@-Z\\-_]|\[[0-?]*[ -/]*[@-~])').sub('', text_line)
                            if not text_line.endswith("\n"):
                                text_line += "\n"
                            result += f"# {text_line}"
            result += "\n"
    # print(result)
    with open(write_fpath, "w") as f:
        f.write(result)
# Out:
# ./4_controlflow/1_if_statements.py
# ./4_controlflow/2_for_statements.py
# ./4_controlflow/3_the_range_function.py
# ./4_controlflow/4_break_and_continue_statements.py
# ./4_controlflow/5_else_clauses_on_loops.py
# ./4_controlflow/6_pass_statements.py
# ./4_controlflow/7_match_statements.py
# ./4_controlflow/8_defining_functions.py
# ./4_controlflow/9_1_default_argument_values.py
# ./4_controlflow/9_2_keyword_arguments.py
# ./4_controlflow/9_3_special_parameters.py
# ./4_controlflow/9_4_arbitrary_argument_lists.py
# ./4_controlflow/9_5_unpacking_argument_lists.py
# ./4_controlflow/9_6_lambda_expressions.py
# ./4_controlflow/9_7_documentation_strings.py
# ./4_controlflow/9_8_function_annotations.py
# ./2_interpreter/1_invoking_the_interpreter.py
# ./3_introduction/__introduction.py
# ./3_introduction/1_0_an_informal_introduction_to_python.py
# ./3_introduction/2_first_steps_towards_programming.py
# ./3_introduction/1_3_lists.py
# ./3_introduction/1_2_text.py
# ./3_introduction/1_1_numbers.py
