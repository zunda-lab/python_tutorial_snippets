# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
from pprint import pprint
import json
import re

# %%
os.chdir("/content/drive/MyDrive/Colab Notebooks/python_activities/python_tutorial_snippets/notebook/10_stdlib")
read_fpaths = glob.glob('./**/*.ipynb', recursive=True)
pprint(read_fpaths)
# Out:
# ['./1_operating_system_interface.ipynb',
#  './2_file_wildcards.ipynb',
#  './3_command_line_arguments.ipynb',
#  './4_error_output_redirection_and_program_termination.ipynb',
#  './5_string_pattern_matching.ipynb',
#  './6_mathematics.ipynb',
#  './10_performance_measurement.ipynb',
#  './9_data_compression.ipynb',
#  './8_dates_and_times.ipynb',
#  './7_internet_access.ipynb',
#  './11_quality_control.ipynb']

# %%
for read_fpath in read_fpaths:
    # print(fname)
    result = ""
    dir_path = os.path.dirname(read_fpath)
    basename_without_ext = os.path.splitext(os.path.basename(read_fpath))[0]
    write_fpath = f"{dir_path}/{basename_without_ext}.py"
    print(write_fpath)
    with open(read_fpath, "r") as f:
        nb = json.load(f)
        # pprint(nb)
        for cell in nb["cells"]:
            for source_line in cell["source"]:
                result += source_line
            result += "\n"
            for output in cell["outputs"]:
                output_type = output["output_type"]
                match output_type:
                    case "execute_result":
                        for text_line in output["data"]["text/plain"]:
                            result += f"# {text_line}\n"
                    case "display_data":
                        for text_line in output["data"]["text/plain"]:
                            result += f"# {text_line}\n"
                    case "stream":
                        for text_line in output["text"]:
                            result += f"# {text_line}"
                    case "error":
                        for text_line in output["traceback"]:
                            text_line = re.compile(r'\x1B(?:[@-Z\\-_]|\[[0-?]*[ -/]*[@-~])').sub('', text_line)
                            if not text_line.endswith("\n"):
                                text_line += "\n"
                            result += f"# {text_line}"
            result += "\n"
    # print(result)
    with open(write_fpath, "w") as f:
        f.write(result)
# Out:
# ./1_operating_system_interface.py
# ./2_file_wildcards.py
# ./3_command_line_arguments.py
# ./4_error_output_redirection_and_program_termination.py
# ./5_string_pattern_matching.py
# ./6_mathematics.py
# ./10_performance_measurement.py
# ./9_data_compression.py
# ./8_dates_and_times.py
# ./7_internet_access.py
# ./11_quality_control.py
