# %%
class MyClass:
    """A simple example class"""
    i = 12345

    def f(self):
        return 'hello world'

# %%
x = MyClass()

# %%
def __init__(self):
    self.data = []

# %%
x = MyClass()

# %%
class Complex:
    def __init__(self, realpart, imagpart):
        self.r = realpart
        self.i = imagpart

x = Complex(3.0, -4.5)
x.r, x.i
# Out:
# (3.0, -4.5)
